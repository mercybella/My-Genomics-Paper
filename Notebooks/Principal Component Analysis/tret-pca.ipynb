# %%
# %pip install -q --no-warn-conflicts malariagen_data
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 33.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 4.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.9/252.9 kB 15.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 67.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.7/71.7 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 82.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 775.9/775.9 kB 35.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.8/47.8 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 78.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.8/25.8 MB 18.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 102.3 MB/s eta 0:00:00
# ...

# %%
import malariagen_data
import os
import plotly.io as pio
pio.renderers.default = "notebook+colab"

# %%
ag3 = malariagen_data.Ag3()
ag3
# Out:
# <MalariaGEN Ag3 API client>
# Storage URL                           : gs://vo_agam_release_master_us_central1/
# Data releases available               : 3.0, 3.1, 3.2, 3.3, 3.4, 3.5, 3.6, 3.7, 3.8, 3.9, 3.10, 3.11, 3.12, 3.13, 3.14, 3.15, 3.16
# Results cache                         : /content/drive/MyDrive/Colab Data/ag3-structure-results
# Cohorts analysis                      : 20260120
# AIM analysis                          : 20220528
# Site filters analysis                 : dt_20200416
# Software version                      : malariagen_data 15.7.0
# Client location                       : Oregon, United States (Google Cloud us-west1)
# Data filtered to unrestricted use only: False
# Data filtered to surveillance use only: False
# Relevant data releases                : 3.0, 3.1, 3.2, 3.3, 3.4, 3.5, 3.6, 3.7, 3.8, 3.9, 3.10, 3.11, 3.12, 3.13, 3.14, 3.15, 3.16
# ---
# Please note that data are subject to terms of use,
# for more information see https://www.malariagen.net/data
# ...

# %%
#This sets the variable of the genomic region of TREH and the no of snps estimated to be within that region
region = "2L: 17,066,531-17,082,025"
n_snps = 2000

# %%
pca_bf_df, evr_bf = ag3.pca(
    region=region,
    n_snps=n_snps,
    sample_sets="3.0",
);
# Out:
# Compute biallelic diplotypes:   0%|          | 0/301 [00:00<?, ?it/s]

# %%
evr_bf
# Out:
# array([0.01307091, 0.0078721 , 0.00642154, 0.00498514, 0.00476035,
#        0.00451042, 0.00438872, 0.00401417, 0.00383936, 0.00380498,
#        0.00370212, 0.00364541, 0.00360913, 0.00356162, 0.00345472,
#        0.00342763, 0.00338609, 0.00331678, 0.00325789, 0.00323324],
#       dtype=float32)

# %%
#Allows us to see the variance that exist in a bar chart bewteen PCs which will further inform our decision on which PCs to use for the plot
ag3.plot_pca_variance(evr_bf)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
pca_bf_df.to_excel("uftret_pca.xlsx")

# %%
#To filter out samples with taxon labelled "unassigned"
fpca_bf_df= pca_bf_df.query("taxon != 'unassigned'")
fpca_bf_df.to_excel("tret_pca.xlsx")
fpca_bf_df
# Out:
#      sample_id       PC1       PC2        PC3        PC4        PC5       PC6  \
# 0     AR0047-C -4.098364 -2.311292   0.789529   2.593353  -0.332886 -3.272541
# 1     AR0049-C -2.400392 -3.423430   2.103800   3.450302   4.227360 -0.155612
# 2     AR0051-C -3.807113 -3.940368   0.818565   4.400170   2.240748 -0.174191
# 3     AR0061-C -1.686603 -4.470038  -0.764932   3.517942   2.474556 -2.032161
# 4     AR0078-C -2.653858 -3.008318   1.878846   3.590924   5.962986 -2.618148
# ...        ...       ...       ...        ...        ...        ...       ...
# 2779  AC0295-C -3.120977 -0.775479  -2.191703   0.041978   1.418755  3.644120
# 2780  AC0296-C -2.500650  0.359129 -10.556436 -11.772983  22.878632 -4.565578
# 2781  AC0297-C -2.612111 -3.521366  -4.661728  -4.102910   5.210516  8.382420
# 2782  AC0298-C -2.049964 -3.730469  -2.329819   7.024030  -6.073217 -2.095280
# 2783  AC0299-C -3.017475 -0.592676  -3.873199   3.541292  -1.272403  1.538976
#
# ...

# %%
#To plot a two dimensional PCA 
ag3.plot_pca_coords(
    fpca_bf_df,
    color="taxon",
    title="Taxonomic structure of TRET"
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
